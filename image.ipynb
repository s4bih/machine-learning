# %% [markdown]
# <a href="https://colab.research.google.com/github/s4bih/machine-learning/blob/main/image.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import random

# %%
x = [random.randint(1,10)for i in range(10)]
y = [random.randint(1,10)for i in range(10)]
plt.plot(x,y)
plt.show()
plt.title('Scatter Plot')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
# Out:
# Text(0, 0.5, 'Y-Axis')

# %%
img = mpimg.imread('/content/Untitled Project - .png')
plt.imshow(img)
plt.axis('off')
plt.show()

# %%
import numpy as np

array = np.arange(5)
print(array)

squared_array = array ** 2
print(squared_array)

arrrray = np.sum(array)
print(arrrray)
# Out:
# [0 1 2 3 4]
# [ 0  1  4  9 16]
# 10

# %%
m = 2
c =10
x = np.linspace(0,10,100)
y = m*x + c
plt.plot(y)
