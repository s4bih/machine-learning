# %% [markdown]
# <a href="https://colab.research.google.com/github/s4bih/machine-learning/blob/main/gaji.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # data

# %%
import pandas as pd
file_id = '1rm-AAkYYVHcpUu4yLP-D1d2D7FETgD-P'
url = 'https://drive.google.com/uc?id={}'.format(file_id)

# %%
data = pd.read_csv(url)

# %%
data
# Out:
#    experience  test_score  interview_score  Salary
# 0         NaN         8.0              8.0   50000
# 1         NaN         5.0              4.0   22000
# 2       three         6.0              5.0   30000
# 3        five         9.0              9.0   55000
# 4         six         3.0              5.0   13000
# 5         NaN         2.0              1.0    9000
# 6         ten         8.0              6.0   48000
# 7         one         1.0              2.0     500
# 8     fifteen         9.0              9.0   60000
# 9    thirteen         7.5              7.5   45000
# 10        ten         NaN              5.0   25000
# 11        NaN         1.0              1.0     500
# 12        one         3.0              6.0   25000
# 13       four         5.0              4.0   36000
# 14        six         5.0              NaN    8000
# 15     eleven         9.0              8.0   55000
# 16     twelve         9.0              9.0   58000
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   experience       15 non-null     object
#  1   test_score       19 non-null     float64
#  2   interview_score  19 non-null     float64
#  3   Salary           20 non-null     int64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 772.0+ bytes

# %%
data.describe()
# Out:
#        test_score  interview_score        Salary
# count   19.000000        19.000000     20.000000
# mean     5.447368         5.657895  30350.000000
# std      2.832817         2.516902  19780.439567
# min      1.000000         1.000000    500.000000
# 25%      3.000000         4.500000  12750.000000
# 50%      5.000000         6.000000  27500.000000
# 75%      8.000000         7.750000  48500.000000
# max      9.000000         9.000000  60000.000000

# %%
data.isnull().sum()
# Out:
# experience         5
# test_score         1
# interview_score    1
# Salary             0
# dtype: int64

# %%
data['experience'].value_counts()
# Out:
# experience
# three       2
# five        2
# six         2
# ten         2
# one         2
# fifteen     1
# thirteen    1
# four        1
# eleven      1
# twelve      1
# Name: count, dtype: int64

# %%
ordinal_values = {'one':1, 'two':2, 'three':3, 'four':4, 'five':5, 'six':6, 'seven':7, 'eight':8, 'nine':9, 'ten':10, 'eleven':11, 'twelve':12,'thirteen':13,'fifteen':15}
data['experience'] = data['experience'].map(ordinal_values)

# %%
data['experience']
# Out:
# 0      NaN
# 1      NaN
# 2      3.0
# 3      5.0
# 4      6.0
# 5      NaN
# 6     10.0
# 7      1.0
# 8     15.0
# 9     13.0
# 10    10.0
# 11     NaN
# 12     1.0
# 13     4.0
# 14     6.0
# 15    11.0
# 16    12.0
# 17     NaN
# 18     3.0
# 19     5.0
# Name: experience, dtype: float64

# %%
mean_experience = data['experience'].mean()
data['experience'] = data['experience'].fillna(mean_experience)

# %%
data['experience']
# Out:
# 0      7.0
# 1      7.0
# 2      3.0
# 3      5.0
# 4      6.0
# 5      7.0
# 6     10.0
# 7      1.0
# 8     15.0
# 9     13.0
# 10    10.0
# 11     7.0
# 12     1.0
# 13     4.0
# 14     6.0
# 15    11.0
# 16    12.0
# 17     7.0
# 18     3.0
# 19     5.0
# Name: experience, dtype: float64

# %%
#fill mising'tesr score'with meaaa
mean_test_score = data['test_score'].mean()
data['test_score'] = data['test_score'].fillna(mean_test_score)
data['test_score']
# Out:
# 0     8.000000
# 1     5.000000
# 2     6.000000
# 3     9.000000
# 4     3.000000
# 5     2.000000
# 6     8.000000
# 7     1.000000
# 8     9.000000
# 9     7.500000
# 10    5.447368
# 11    1.000000
# 12    3.000000
# 13    5.000000
# 14    5.000000
# 15    9.000000
# 16    9.000000
# 17    2.000000
# 18    5.000000
# 19    6.000000
# Name: test_score, dtype: float64

# %%
mean_test_score = data['interview_score'].mean()
data['interview_score'] = data['interview_score'].fillna(mean_test_score)
data['interview_score']
# Out:
# 0     8.000000
# 1     4.000000
# 2     5.000000
# 3     9.000000
# 4     5.000000
# 5     1.000000
# 6     6.000000
# 7     2.000000
# 8     9.000000
# 9     7.500000
# 10    5.000000
# 11    1.000000
# 12    6.000000
# 13    4.000000
# 14    5.657895
# 15    8.000000
# 16    9.000000
# 17    6.000000
# 18    5.000000
# 19    7.000000
# Name: interview_score, dtype: float64

# %%
data
# Out:
#     experience  test_score  interview_score  Salary
# 0          7.0    8.000000         8.000000   50000
# 1          7.0    5.000000         4.000000   22000
# 2          3.0    6.000000         5.000000   30000
# 3          5.0    9.000000         9.000000   55000
# 4          6.0    3.000000         5.000000   13000
# 5          7.0    2.000000         1.000000    9000
# 6         10.0    8.000000         6.000000   48000
# 7          1.0    1.000000         2.000000     500
# 8         15.0    9.000000         9.000000   60000
# 9         13.0    7.500000         7.500000   45000
# 10        10.0    5.447368         5.000000   25000
# 11         7.0    1.000000         1.000000     500
# 12         1.0    3.000000         6.000000   25000
# 13         4.0    5.000000         4.000000   36000
# 14         6.0    5.000000         5.657895    8000
# 15        11.0    9.000000         8.000000   55000
# 16        12.0    9.000000         9.000000   58000
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#create bar plot base on experience
sns.barplot(x='experience', y='test_score', data=data)
plt.title('Experience vs Test Score')
plt.xlabel('Experience')
plt.ylabel('Test Score')
plt.show()

# %%
#create a joint plot for test vs interview score
sns.jointplot(x='test_score', y='interview_score', data=data)

plt.xlabel('Test Score')
plt.ylabel('Interview Score')
plt.show()

# %%
#CREATE A LINE PLOT FOR EXPERIENCE VS SALARY
sns.lineplot(x='experience', y='Salary', data=data)
plt.title('Experience vs Salary')
plt.xlabel('Experience')
plt.ylabel('Salary')
plt.show()

# %%
#pair pair plot
sns.pairplot(data)
plt.show()

# %%
# Features are the input variables that help us predict the target
# In this case, 'Experience', 'Test Score', and 'Interview Score' are the features
features = data.drop(columns = ['Salary'], axis=1)

# %%
# Target is the variable we want to predict
# In this case, 'Salary' is the target
target = data['Salary']

# %%
from sklearn.model_selection import train_test_split

# %%
features_train, features_test, target_train, target_test = train_test_split(features, target, test_size=0.2, random_state=42)

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(features_train, target_train)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

# %%
linear_pred = model.predict(features_test)

# %%
linear_pred
# Out:
# array([47647.31582367, 10304.25333471, 54098.17149002, 26048.18524525])

# %%
#calculate mea for linar req model
linear_mea = mean_squared_error(target_test, linear_pred)
r2 = r2_score(target_test, linear_pred)
mse = mean_squared_error(target_test, linear_pred)

# %%
print('mean', linear_mea)
print('mean squared error', mse)
print('r2 score',r2)
# Out:
# mean 6402944.506927436
# mean squared error 6402944.506927436
# r2 score 0.9806374764485278

# %% [markdown]
# prediction

# %%
new_experience = int(input('experience:'))
new_test_score = int(input('test_score:'))
new_interview_score = int(input('interview_score:'))

new_data = {
    'experience': new_experience,
    'test_score': new_test_score,
    'interview_score': new_interview_score
}

new_data_df = pd.DataFrame([new_data])

predicted_salary = model.predict(new_data_df)
print('Predicted Salary:', round(predicted_salary[0]))
# Out:
# experience:4
# test_score:5
# interview_score:3
# Predicted Salary: 24658
